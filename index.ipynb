# %% [markdown]
# # Understanding Pandas Series and DataFrames - Lab

# %% [markdown]
# # Introduction
#
# In this lab, let's get some hands on practice working with data cleanup using Pandas.

# %% [markdown]
# ## Objectives
# You will be able to:
#
# * Manipulate columns in DataFrames (df.rename, df.drop)
# * Manipulate the index in DataFrames (df.reindex, df.drop, df.rename)
# * Manipulate column datatypes

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
df = pd.read_csv('turnstile_180901.txt')
print(len(df))
df.head()
# Out:
# 197625
#     C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  08:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  12:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  16:00:00
#
#       DESC  ENTRIES  \
# 0  REGULAR  6736067
# 1  REGULAR  6736087
# 2  REGULAR  6736105
# 3  REGULAR  6736180
# 4  REGULAR  6736349
#
#    EXITS
# 0                                            2283184
# 1                                            2283188
# 2                                            2283229
# 3                                            2283314
# 4                                            2283384

# %% [markdown]
# # Practice
#
# ## Objectives
# You will be able to:
# * Understand and explain what Pandas Series and DataFrames are and how they differ from dictionaries and lists
# * Create Series & DataFrames from dictionaries and lists
# * Manipulate columns in DataFrames (df.rename, df.drop)
# * Manipulate the index in DataFrames (df.reindex, df.drop, df.rename)
# * Manipulate column datatypes

# %% [markdown]
# # Rename all the columns to lower case

# %%
#Your code here
dfk = df
dfk.columns = map(str.lower,dfk.columns)
dfk.columns
# Out:
# Index(['c/a', 'unit', 'scp', 'station', 'linename', 'division', 'date', 'time',
#        'desc', 'entries',
#        'exits                                                               '],
#       dtype='object')

# %%
dfk.columns = map(str.strip, dfk.columns)
dfk.columns
# Out:
# Index(['c/a', 'unit', 'scp', 'station', 'linename', 'division', 'date', 'time',
#        'desc', 'entries', 'exits'],
#       dtype='object')

# %% [markdown]
# # Change the Index to be the Line Names

# %%
dfk = df.set_index('linename')
dfk
# Out:
#             c/a  unit       scp        station division        date      time  \
# linename
# NQR456W    A002  R051  02-00-00          59 ST      BMT  08/25/2018  00:00:00
# NQR456W    A002  R051  02-00-00          59 ST      BMT  08/25/2018  04:00:00
# NQR456W    A002  R051  02-00-00          59 ST      BMT  08/25/2018  08:00:00
# NQR456W    A002  R051  02-00-00          59 ST      BMT  08/25/2018  12:00:00
# NQR456W    A002  R051  02-00-00          59 ST      BMT  08/25/2018  16:00:00
# NQR456W    A002  R051  02-00-00          59 ST      BMT  08/25/2018  20:00:00
# NQR456W    A002  R051  02-00-00          59 ST      BMT  08/26/2018  00:00:00
# NQR456W    A002  R051  02-00-00          59 ST      BMT  08/26/2018  04:00:00
# NQR456W    A002  R051  02-00-00          59 ST      BMT  08/26/2018  08:00:00
# NQR456W    A002  R051  02-00-00          59 ST      BMT  08/26/2018  12:00:00
# NQR456W    A002  R051  02-00-00          59 ST      BMT  08/26/2018  16:00:00
# ...

# %%
dfk.tail()
# Out:
#             c/a  unit       scp        station division        date      time  \
# linename
# R         TRAM2  R469  00-05-01  RIT-ROOSEVELT      RIT  08/31/2018  05:00:00
# R         TRAM2  R469  00-05-01  RIT-ROOSEVELT      RIT  08/31/2018  09:00:00
# R         TRAM2  R469  00-05-01  RIT-ROOSEVELT      RIT  08/31/2018  13:00:00
# R         TRAM2  R469  00-05-01  RIT-ROOSEVELT      RIT  08/31/2018  17:00:00
# R         TRAM2  R469  00-05-01  RIT-ROOSEVELT      RIT  08/31/2018  21:00:00
#
#              desc  entries  exits
# linename
# R         REGULAR     5554    348
# R         REGULAR     5554    348
# R         REGULAR     5554    348
# R         REGULAR     5554    348
# R         REGULAR     5554    348

# %% [markdown]
# # Painstakingly change the index back

# %%
dfk['linename'] = dfk.index
dfk.head()
# Out:
#            c/a  unit       scp station division        date      time  \
# linename
# NQR456W   A002  R051  02-00-00   59 ST      BMT  08/25/2018  00:00:00
# NQR456W   A002  R051  02-00-00   59 ST      BMT  08/25/2018  04:00:00
# NQR456W   A002  R051  02-00-00   59 ST      BMT  08/25/2018  08:00:00
# NQR456W   A002  R051  02-00-00   59 ST      BMT  08/25/2018  12:00:00
# NQR456W   A002  R051  02-00-00   59 ST      BMT  08/25/2018  16:00:00
#
#              desc  entries    exits linename
# linename
# NQR456W   REGULAR  6736067  2283184  NQR456W
# NQR456W   REGULAR  6736087  2283188  NQR456W
# NQR456W   REGULAR  6736105  2283229  NQR456W
# NQR456W   REGULAR  6736180  2283314  NQR456W
# NQR456W   REGULAR  6736349  2283384  NQR456W

# %%
dfk.index = range(len(dfk.index))
dfk.head()
# Out:
#     c/a  unit       scp station division        date      time     desc  \
# 0  A002  R051  02-00-00   59 ST      BMT  08/25/2018  00:00:00  REGULAR
# 1  A002  R051  02-00-00   59 ST      BMT  08/25/2018  04:00:00  REGULAR
# 2  A002  R051  02-00-00   59 ST      BMT  08/25/2018  08:00:00  REGULAR
# 3  A002  R051  02-00-00   59 ST      BMT  08/25/2018  12:00:00  REGULAR
# 4  A002  R051  02-00-00   59 ST      BMT  08/25/2018  16:00:00  REGULAR
#
#    entries    exits linename
# 0  6736067  2283184  NQR456W
# 1  6736087  2283188  NQR456W
# 2  6736105  2283229  NQR456W
# 3  6736180  2283314  NQR456W
# 4  6736349  2283384  NQR456W

# %% [markdown]
# ## Create another column 'Num_Lines' that is a count of how many lines pass through a station. Then sort your dataframe by this column in descending order.

# %%
dfk['Num_Lines'] = dfk['linename'].apply(len)
dfk.tail()
# Out:
#           c/a  unit       scp        station division        date      time  \
# 197620  TRAM2  R469  00-05-01  RIT-ROOSEVELT      RIT  08/31/2018  05:00:00
# 197621  TRAM2  R469  00-05-01  RIT-ROOSEVELT      RIT  08/31/2018  09:00:00
# 197622  TRAM2  R469  00-05-01  RIT-ROOSEVELT      RIT  08/31/2018  13:00:00
# 197623  TRAM2  R469  00-05-01  RIT-ROOSEVELT      RIT  08/31/2018  17:00:00
# 197624  TRAM2  R469  00-05-01  RIT-ROOSEVELT      RIT  08/31/2018  21:00:00
#
#            desc  entries  exits linename  Num_Lines
# 197620  REGULAR     5554    348        R          1
# 197621  REGULAR     5554    348        R          1
# 197622  REGULAR     5554    348        R          1
# 197623  REGULAR     5554    348        R          1
# 197624  REGULAR     5554    348        R          1

# %%
# Your code here

# %% [markdown]
# ## Write a function to clean a column name.

# %%
def clean(col_name):
    cleaned = col_name.strip()
    return cleaned

# %%
#This is a list comprehension. It applies your clean function to every item in the list.
#We then reassign that to df.columns
#You shouldn't have to change anything here.
#Your function above should work appropriately here.
dfk.columns = [clean(col) for col in dfk.columns]

# %%
#Checking the output, we can see the results.
dfk.dtype()
# Out:
# AttributeErrorTraceback (most recent call last)
# <ipython-input-89-c92d5deaa3c9> in <module>()
#       1 #Checking the output, we can see the results.
# ----> 2 dfk.dtype()
#
# /opt/conda/envs/learn-env/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    4374             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4375                 return self[name]
# -> 4376             return object.__getattribute__(self, name)
#    4377
#    4378     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'dtype'

# %% [markdown]
# ## Compare subway traffic by day of the week. Display this as a graph.

# %%
#Your code here

"""Must make date into datetime type, then can apply weekday"""
dfk['date']=pd.to_datetime(dfk['date'])
dfk.head()
# Out:
#     c/a  unit       scp station division       date      time     desc  \
# 0  A002  R051  02-00-00   59 ST      BMT 2018-08-25  00:00:00  REGULAR
# 1  A002  R051  02-00-00   59 ST      BMT 2018-08-25  04:00:00  REGULAR
# 2  A002  R051  02-00-00   59 ST      BMT 2018-08-25  08:00:00  REGULAR
# 3  A002  R051  02-00-00   59 ST      BMT 2018-08-25  12:00:00  REGULAR
# 4  A002  R051  02-00-00   59 ST      BMT 2018-08-25  16:00:00  REGULAR
#
#    entries    exits linename  Num_Lines
# 0  6736067  2283184  NQR456W          7
# 1  6736087  2283188  NQR456W          7
# 2  6736105  2283229  NQR456W          7
# 3  6736180  2283314  NQR456W          7
# 4  6736349  2283384  NQR456W          7

# %%
dfk['weekday']=dfk.date.dt.dayofweek
dfk.head()
# Out:
#     c/a  unit       scp station division       date      time     desc  \
# 0  A002  R051  02-00-00   59 ST      BMT 2018-08-25  00:00:00  REGULAR
# 1  A002  R051  02-00-00   59 ST      BMT 2018-08-25  04:00:00  REGULAR
# 2  A002  R051  02-00-00   59 ST      BMT 2018-08-25  08:00:00  REGULAR
# 3  A002  R051  02-00-00   59 ST      BMT 2018-08-25  12:00:00  REGULAR
# 4  A002  R051  02-00-00   59 ST      BMT 2018-08-25  16:00:00  REGULAR
#
#    entries    exits linename  Num_Lines  weekday
# 0  6736067  2283184  NQR456W          7        5
# 1  6736087  2283188  NQR456W          7        5
# 2  6736105  2283229  NQR456W          7        5
# 3  6736180  2283314  NQR456W          7        5
# 4  6736349  2283384  NQR456W          7        5

# %%
grouped = dfk.groupby('weekday').sum()
grouped.plot(kind='barh')

# %%
grouped
# Out:
#                entries         exits  Num_Lines
# weekday
# 0        1114237052454  911938153513      76110
# 1        1143313287046  942230721477      77303
# 2        1123655222441  920630864687      75713
# 3        1122723988662  920691927110      76607
# 4        1110224700078  906799065337      75573
# 5        1115661545514  909142081474      74725
# 6        1192306179082  959223750461      75306

# %%
grouped = grouped.reset_index()
grouped.head()
# Out:
#    weekday        entries         exits  Num_Lines
# 0        0  1114237052454  911938153513      76110
# 1        1  1143313287046  942230721477      77303
# 2        2  1123655222441  920630864687      75713
# 3        3  1122723988662  920691927110      76607
# 4        4  1110224700078  906799065337      75573

# %% [markdown]
# ## Is there more subway traffic on a weekend or a weekday?    Be specific in comparing magnitudes.

# %%
#Your code here
grouped['isWeekend'] = grouped.weekday.map({0:False,1:False,2:False,3:False,4:False,5:True,6:True})
wkend = grouped.groupby('isWeekend').mean()
wkend[['entries', 'exits']].plot(kind='barh')

# %% [markdown]
# # Drop a couple of columns

# %%
# Your code here
